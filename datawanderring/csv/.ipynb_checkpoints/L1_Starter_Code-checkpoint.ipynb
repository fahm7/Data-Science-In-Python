# %% [markdown]
# ## Load Data from CSVs

# %%
import unicodecsv

## Longer version of code (replaced with shorter, equivalent version below)

# enrollments = []
# f = open('enrollments.csv', 'rb')
# reader = unicodecsv.DictReader(f)
# for row in reader:
#     enrollments.append(row)
# f.close()


def read_csv(filename):
    with open(filename, 'rb') as f:
        reader = unicodecsv.DictReader(f)
        return list(reader)


enrollments = read_csv('enrollments.csv')
daily_engagement = read_csv('daily_engagement.csv')
project_submissions = read_csv('project_submissions.csv')

# %%
from datetime import datetime as dt

# Takes a date as a string, and returns a Python datetime object. 
# If there is no date given, returns None
def parse_date(date):
    if date == '':
        return None
    else:
        return dt.strptime(date, '%Y-%m-%d')
    
# Takes a string which is either an empty string or represents an integer,
# and returns an int or None.
def parse_maybe_int(i):
    if i == '':
        return None
    else:
        return int(i)

# Clean up the data types in the enrollments table
for enrollment in enrollments:
    enrollment['cancel_date'] = pars_date(enrollment['cancel_date'])
    enrollment['days_to_cancel'] = parse_maybe_int(enrollment['days_to_cancel'])
    enrollment['is_canceled'] = enrollment['is_canceled'] == 'True'
    enrollment['is_udacity'] = enrollment['is_udacity'] == 'True'
    enrollment['join_date'] = parse_date(enrollment['join_date'])
    
enrollments[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-e33afefbcd90> in <module>()
#      19 # Clean up the data types in the enrollments table
#      20 for enrollment in enrollments:
# ---> 21     enrollment['cancel_date'] = pars_date(enrollment['cancel_date'])
#      22     enrollment['days_to_cancel'] = parse_maybe_int(enrollment['days_to_cancel'])
#      23     enrollment['is_canceled'] = enrollment['is_canceled'] == 'True'
#
# NameError: name 'pars_date' is not defined

# %% [markdown]
# ## Fixing Data Types

# %%
# Clean up the data types in the engagement table
for engagement_record in daily_engagement:
    engagement_record['lessons_completed'] = int(float(engagement_record['lessons_completed']))
    engagement_record['num_courses_visited'] = int(float(engagement_record['num_courses_visited']))
    engagement_record['projects_completed'] = int(float(engagement_record['projects_completed']))
    engagement_record['total_minutes_visited'] = float(engagement_record['total_minutes_visited'])
    engagement_record['utc_date'] = parse_date(engagement_record['utc_date'])
    
daily_engagement[0]
# Out:
# OrderedDict([('account_key', '0'),
#              ('utc_date', datetime.datetime(2015, 1, 9, 0, 0)),
#              ('num_courses_visited', 1),
#              ('total_minutes_visited', 11.6793745),
#              ('lessons_completed', 0),
#              ('projects_completed', 0)])

# %%
# Clean up the data types in the submissions table
for submission in project_submissions:
    submission['completion_date'] = parse_date(submission['completion_date'])
    submission['creation_date'] = parse_date(submission['creation_date'])

project_submissions[0]
# Out:
# OrderedDict([('creation_date', datetime.datetime(2015, 1, 14, 0, 0)),
#              ('completion_date', datetime.datetime(2015, 1, 16, 0, 0)),
#              ('assigned_rating', 'UNGRADED'),
#              ('account_key', '256'),
#              ('lesson_key', '3176718735'),
#              ('processing_state', 'EVALUATED')])

# %% [markdown]
# ## Investigating the Data

# %%
len(enrollments)

unique_enrolled_students = set()
for enrollment in enrollments:
    unique_enrolled_students.add(enrollment['account_key'])
len(unique_enrolled_students)

len(daily_engagement)

unique_engagement_students = set()
for engagement_record in daily_engagement:
    unique_engagement_students.add(engagement_record['account_key'])
len(unique_engagement_students)

len(project_submissions)

unique_project_submitters = set()
for submission in project_submissions:
    unique_project_submitters.add(submission['account_key'])
len(unique_project_submitters)

unique_enrolled_students = set()
for enrollment in enrollments:
    unique_enrolled_students.add(enrollment['account_key'])
len(unique_enrolled_students)

len(daily_engagement)


## Find the total number of rows and the number of unique students (account keys)
## in each table.
# Out:
# 136240

# %% [markdown]
# ## Problems in the Data

# %%
for engagement_record in daily_engagement:
    engagement_record['account_key'] = engagement_record['account_key']
    del[engagement_record['account_key']]
#####################################
#                 3                 #
#####################################


unique_engagement_students = set()
for engagement_record in daily_engagement:
    unique_engagement_students.add(engagement_record['account_key'])
len(unique_engagement_students)

len(project_submissions)
## Rename the "acct" column in the daily_engagement table to "account_key".
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-0674ed0c282b> in <module>()
#       8 unique_engagement_students = set()
#       9 for engagement_record in daily_engagement:
# ---> 10     unique_engagement_students.add(engagement_record['account_key'])
#      11 len(unique_engagement_students)
#      12
#
# KeyError: 'account_key'

# %% [markdown]
# ## Missing Engagement Records

# %%
for enrollment in enrollments:
    student = enrollment['account_key']
    if student not in unique_engagement_students:
        print (enrollment)
        break
unique_project_submitters = set()
for submission in project_submissions:
    unique_project_submitters.add(submission['account_key'])
len(unique_project_submitters)

## Find any one student enrollments where the student is missing from the daily engagement table.
## Output that enrollment.
# Out:
# OrderedDict([('account_key', '448'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 14, 0, 0)), ('days_to_cancel', 65), ('is_udacity', True), ('is_canceled', True)])
# 743

# %% [markdown]
# ## Checking for More Problem Records

# %%
num_problem_students = 0
for enrollment in enrollments:
    student = enrollment['account_key']
    if (student not in unique_engagement_students and 
            enrollment['join_date'] != enrollment['cancel_date']):
        print (enrollment)
        num_problem_students += 1

num_problem_students

## Find the number of surprising data points (enrollments missing from
## the engagement table) that remain, if any.
# Out:
# OrderedDict([('account_key', '448'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 14, 0, 0)), ('days_to_cancel', 65), ('is_udacity', True), ('is_canceled', True)])
# OrderedDict([('account_key', '448'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 5, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 10, 0, 0)), ('days_to_cancel', 5), ('is_udacity', True), ('is_canceled', True)])
# OrderedDict([('account_key', '448'), ('status', 'current'), ('join_date', datetime.datetime(2015, 3, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', True), ('is_canceled', False)])
# OrderedDict([('account_key', '448'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 1, 14, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 27, 0, 0)), ('days_to_cancel', 13), ('is_udacity', True), ('is_canceled', True)])
# OrderedDict([('account_key', '448'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 1, 27, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 42), ('is_udacity', True), ('is_canceled', True)])
# OrderedDict([('account_key', '700'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 16, 0, 0)), ('days_to_cancel', 6), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '429'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 120), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '429'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 3, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 6, 17, 0, 0)), ('days_to_cancel', 99), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '60'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 14, 0, 0)), ('days_to_cancel', 65), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '60'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 1, 14, 0, 0)), ('cancel_date', datetime.datetime(2015, 4, 1, 0, 0)), ('days_to_cancel', 77), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '60'), ('status', 'current'), ('join_date', datetime.datetime(2015, 4, 1, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1300'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 16, 0, 0)), ('days_to_cancel', 6), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '369'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '322'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 2, 2, 0, 0)), ('days_to_cancel', 84), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '322'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 2, 12, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 26), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '322'), ('status', 'current'), ('join_date', datetime.datetime(2015, 3, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '336'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '553'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '584'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 14, 0, 0)), ('days_to_cancel', 65), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '584'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 1, 14, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 55), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '584'), ('status', 'current'), ('join_date', datetime.datetime(2015, 3, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1006'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 17, 0, 0)), ('days_to_cancel', 7), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '458'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 4, 1, 0, 0)), ('days_to_cancel', 142), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '458'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 4, 4, 0, 0)), ('cancel_date', datetime.datetime(2015, 4, 6, 0, 0)), ('days_to_cancel', 2), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '458'), ('status', 'current'), ('join_date', datetime.datetime(2015, 4, 6, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1058'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 14, 0, 0)), ('days_to_cancel', 65), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1058'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 1, 14, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 55), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1058'), ('status', 'current'), ('join_date', datetime.datetime(2015, 3, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '206'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '45'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 120), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '45'), ('status', 'current'), ('join_date', datetime.datetime(2015, 3, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '315'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 5, 17, 0, 0)), ('days_to_cancel', 188), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '604'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '204'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '408'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 120), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '408'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 3, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 4, 1, 0, 0)), ('days_to_cancel', 22), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '408'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 4, 1, 0, 0)), ('cancel_date', datetime.datetime(2015, 4, 17, 0, 0)), ('days_to_cancel', 16), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '51'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 120), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '51'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 3, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 6, 17, 0, 0)), ('days_to_cancel', 99), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '323'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 4, 17, 0, 0)), ('days_to_cancel', 158), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '568'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '130'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 120), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '130'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 3, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 4, 1, 0, 0)), ('days_to_cancel', 22), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '130'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 4, 1, 0, 0)), ('cancel_date', datetime.datetime(2015, 6, 17, 0, 0)), ('days_to_cancel', 77), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '550'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 5, 2, 0, 0)), ('days_to_cancel', 173), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '550'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 5, 28, 0, 0)), ('cancel_date', datetime.datetime(2015, 7, 4, 0, 0)), ('days_to_cancel', 37), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '44'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 120), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '44'), ('status', 'current'), ('join_date', datetime.datetime(2015, 3, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1020'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 15, 0, 0)), ('days_to_cancel', 5), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '838'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 11, 0, 0)), ('days_to_cancel', 1), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '198'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '368'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '440'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 11, 0, 0)), ('cancel_date', datetime.datetime(2015, 2, 18, 0, 0)), ('days_to_cancel', 99), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '675'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 11, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 16, 0, 0)), ('days_to_cancel', 5), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '57'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 11, 0, 0)), ('cancel_date', datetime.datetime(2015, 2, 18, 0, 0)), ('days_to_cancel', 99), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '57'), ('status', 'current'), ('join_date', datetime.datetime(2015, 5, 6, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1090'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 11, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 26, 0, 0)), ('days_to_cancel', 15), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '541'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 12, 0, 0)), ('cancel_date', datetime.datetime(2015, 6, 19, 0, 0)), ('days_to_cancel', 219), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '756'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 12, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 15, 0, 0)), ('days_to_cancel', 3), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '756'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 15, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 15, 0, 0)), ('days_to_cancel', 61), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '101'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 12, 0, 0)), ('cancel_date', datetime.datetime(2015, 4, 20, 0, 0)), ('days_to_cancel', 159), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1021'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 12, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 17, 0, 0)), ('days_to_cancel', 5), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1108'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 12, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 16, 0, 0)), ('days_to_cancel', 4), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '800'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 12, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 14, 0, 0)), ('days_to_cancel', 2), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '800'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 3, 4, 0, 0)), ('cancel_date', datetime.datetime(2015, 5, 11, 0, 0)), ('days_to_cancel', 68), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '702'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 13, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 15, 0, 0)), ('days_to_cancel', 2), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '702'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 15, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 14, 0, 0)), ('days_to_cancel', 60), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '702'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 1, 14, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 55), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '702'), ('status', 'current'), ('join_date', datetime.datetime(2015, 3, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '38'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 14, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '215'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 14, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '744'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 14, 0, 0)), ('cancel_date', datetime.datetime(2014, 12, 21, 0, 0)), ('days_to_cancel', 37), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '217'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 14, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 15, 0, 0)), ('days_to_cancel', 1), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '217'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 15, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 115), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '217'), ('status', 'current'), ('join_date', datetime.datetime(2015, 3, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1221'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 14, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 21, 0, 0)), ('days_to_cancel', 7), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1211'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 14, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 15, 0, 0)), ('days_to_cancel', 1), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1211'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 15, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 15, 0, 0)), ('days_to_cancel', 61), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1211'), ('status', 'current'), ('join_date', datetime.datetime(2015, 3, 6, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1051'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 14, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 16, 0, 0)), ('days_to_cancel', 2), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1286'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 14, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 21, 0, 0)), ('days_to_cancel', 7), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '53'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 14, 0, 0)), ('cancel_date', datetime.datetime(2014, 12, 21, 0, 0)), ('days_to_cancel', 37), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '53'), ('status', 'current'), ('join_date', datetime.datetime(2015, 5, 11, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '895'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 14, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 19, 0, 0)), ('days_to_cancel', 5), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '283'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 15, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '283'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 13, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 15, 0, 0)), ('days_to_cancel', 2), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '338'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 15, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 14, 0, 0)), ('days_to_cancel', 60), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '338'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 1, 14, 0, 0)), ('cancel_date', datetime.datetime(2015, 2, 3, 0, 0)), ('days_to_cancel', 20), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '338'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 2, 3, 0, 0)), ('cancel_date', datetime.datetime(2015, 2, 22, 0, 0)), ('days_to_cancel', 19), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '338'), ('status', 'current'), ('join_date', datetime.datetime(2015, 5, 11, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '579'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 15, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '903'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 16, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 21, 0, 0)), ('days_to_cancel', 5), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '627'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 16, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '253'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 16, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 14, 0, 0)), ('days_to_cancel', 59), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '253'), ('status', 'current'), ('join_date', datetime.datetime(2015, 1, 14, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '861'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 16, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 19, 0, 0)), ('days_to_cancel', 3), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '178'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 17, 0, 0)), ('cancel_date', datetime.datetime(2015, 5, 9, 0, 0)), ('days_to_cancel', 173), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '822'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 17, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 15, 0, 0)), ('days_to_cancel', 59), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '822'), ('status', 'current'), ('join_date', datetime.datetime(2015, 7, 18, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '96'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 17, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '123'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 120), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '123'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 3, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 4, 17, 0, 0)), ('days_to_cancel', 38), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '943'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 17, 0, 0)), ('days_to_cancel', 7), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '620'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1204'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2014, 12, 17, 0, 0)), ('days_to_cancel', 37), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '195'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '890'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 11, 0, 0)), ('days_to_cancel', 1), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '354'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '837'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 11, 0, 0)), ('days_to_cancel', 1), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '114'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 11, 0, 0)), ('days_to_cancel', 1), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '114'), ('status', 'current'), ('join_date', datetime.datetime(2015, 5, 8, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '810'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 13, 0, 0)), ('days_to_cancel', 3), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '394'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 4, 17, 0, 0)), ('days_to_cancel', 158), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1253'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 14, 0, 0)), ('days_to_cancel', 65), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1253'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 1, 14, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 20, 0, 0)), ('days_to_cancel', 6), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '504'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 6, 17, 0, 0)), ('days_to_cancel', 219), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '537'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '72'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 5, 17, 0, 0)), ('days_to_cancel', 188), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '268'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2014, 12, 17, 0, 0)), ('days_to_cancel', 37), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '268'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 4, 3, 0, 0)), ('cancel_date', datetime.datetime(2015, 8, 10, 0, 0)), ('days_to_cancel', 129), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '339'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 120), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '339'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 4, 1, 0, 0)), ('cancel_date', datetime.datetime(2015, 6, 17, 0, 0)), ('days_to_cancel', 77), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '339'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 3, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 4, 1, 0, 0)), ('days_to_cancel', 22), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1244'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 14, 0, 0)), ('days_to_cancel', 65), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1244'), ('status', 'current'), ('join_date', datetime.datetime(2015, 3, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1244'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 1, 14, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 55), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1244'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 3, 17, 0, 0)), ('cancel_date', datetime.datetime(2015, 4, 27, 0, 0)), ('days_to_cancel', 41), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1244'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 5, 17, 0, 0)), ('cancel_date', datetime.datetime(2015, 8, 17, 0, 0)), ('days_to_cancel', 92), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '752'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 19, 0, 0)), ('days_to_cancel', 9), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '194'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '520'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 17, 0, 0)), ('days_to_cancel', 127), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '102'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '367'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 11, 0, 0)), ('cancel_date', datetime.datetime(2015, 4, 2, 0, 0)), ('days_to_cancel', 142), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '258'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 7, 17, 0, 0)), ('days_to_cancel', 249), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '522'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1047'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 11, 0, 0)), ('days_to_cancel', 1), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '329'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 14, 0, 0)), ('days_to_cancel', 65), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '329'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 3, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 4, 8, 0, 0)), ('days_to_cancel', 29), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '329'), ('status', 'current'), ('join_date', datetime.datetime(2015, 4, 8, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '329'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 1, 14, 0, 0)), ('cancel_date', datetime.datetime(2015, 2, 3, 0, 0)), ('days_to_cancel', 20), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '329'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 2, 3, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 35), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '225'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '612'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 120), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '612'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 3, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 17, 0, 0)), ('days_to_cancel', 7), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '150'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 5, 17, 0, 0)), ('days_to_cancel', 188), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '179'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 17, 0, 0)), ('days_to_cancel', 127), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '595'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '587'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 14, 0, 0)), ('days_to_cancel', 65), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '587'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 1, 14, 0, 0)), ('cancel_date', datetime.datetime(2015, 4, 17, 0, 0)), ('days_to_cancel', 93), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '587'), ('status', 'current'), ('join_date', datetime.datetime(2015, 5, 28, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '439'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 120), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '439'), ('status', 'current'), ('join_date', datetime.datetime(2015, 3, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '428'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '18'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 2, 17, 0, 0)), ('days_to_cancel', 99), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '544'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 5, 17, 0, 0)), ('days_to_cancel', 188), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '10'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '913'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 14, 0, 0)), ('days_to_cancel', 65), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '913'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 1, 14, 0, 0)), ('cancel_date', datetime.datetime(2015, 2, 17, 0, 0)), ('days_to_cancel', 34), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '23'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '576'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 2, 17, 0, 0)), ('days_to_cancel', 99), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '431'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 17, 0, 0)), ('days_to_cancel', 127), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '223'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '480'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 120), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '480'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 3, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 4, 1, 0, 0)), ('days_to_cancel', 22), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '480'), ('status', 'current'), ('join_date', datetime.datetime(2015, 4, 1, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '525'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 7, 17, 0, 0)), ('days_to_cancel', 249), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1111'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 11, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 119), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1111'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 3, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 4, 1, 0, 0)), ('days_to_cancel', 22), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1111'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 4, 1, 0, 0)), ('cancel_date', datetime.datetime(2015, 4, 18, 0, 0)), ('days_to_cancel', 17), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1107'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 11, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 19, 0, 0)), ('days_to_cancel', 8), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '577'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 12, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 19, 0, 0)), ('days_to_cancel', 68), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '577'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 2, 5, 0, 0)), ('cancel_date', datetime.datetime(2015, 7, 12, 0, 0)), ('days_to_cancel', 157), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '92'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 12, 0, 0)), ('cancel_date', datetime.datetime(2015, 7, 19, 0, 0)), ('days_to_cancel', 249), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '335'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 12, 0, 0)), ('cancel_date', datetime.datetime(2015, 5, 19, 0, 0)), ('days_to_cancel', 188), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '275'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 12, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 16, 0, 0)), ('days_to_cancel', 4), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '275'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 16, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '930'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 13, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 17, 0, 0)), ('days_to_cancel', 4), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '245'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 14, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '135'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 14, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '37'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 14, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '740'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 14, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 15, 0, 0)), ('days_to_cancel', 1), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '740'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 11, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 13, 0, 0)), ('days_to_cancel', 2), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '186'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 14, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '389'), ('status', 'current'), ('join_date', datetime.datetime(2014, 11, 15, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '389'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 14, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 15, 0, 0)), ('days_to_cancel', 1), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '693'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 15, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 14, 0, 0)), ('days_to_cancel', 60), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '693'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 1, 14, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 23, 0, 0)), ('days_to_cancel', 9), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '770'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 15, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 19, 0, 0)), ('days_to_cancel', 4), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '88'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 15, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 115), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '88'), ('status', 'current'), ('join_date', datetime.datetime(2015, 4, 1, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '88'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 3, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 4, 1, 0, 0)), ('days_to_cancel', 22), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '845'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 16, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 23, 0, 0)), ('days_to_cancel', 7), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '983'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 16, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 14, 0, 0)), ('days_to_cancel', 59), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '983'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 1, 14, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 23, 0, 0)), ('days_to_cancel', 9), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1118'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 17, 0, 0)), ('cancel_date', datetime.datetime(2014, 12, 24, 0, 0)), ('days_to_cancel', 37), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1118'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 11, 12, 0, 0)), ('cancel_date', datetime.datetime(2014, 11, 17, 0, 0)), ('days_to_cancel', 5), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '499'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 2, 6, 0, 0)), ('cancel_date', datetime.datetime(2015, 5, 13, 0, 0)), ('days_to_cancel', 96), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '590'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 12, 3, 0, 0)), ('cancel_date', datetime.datetime(2015, 2, 3, 0, 0)), ('days_to_cancel', 62), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '590'), ('status', 'current'), ('join_date', datetime.datetime(2015, 5, 11, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '590'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 2, 3, 0, 0)), ('cancel_date', datetime.datetime(2015, 3, 10, 0, 0)), ('days_to_cancel', 35), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '264'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 12, 3, 0, 0)), ('cancel_date', datetime.datetime(2015, 2, 3, 0, 0)), ('days_to_cancel', 62), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '264'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 2, 3, 0, 0)), ('cancel_date', datetime.datetime(2015, 2, 25, 0, 0)), ('days_to_cancel', 22), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '300'), ('status', 'current'), ('join_date', datetime.datetime(2014, 12, 3, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '54'), ('status', 'current'), ('join_date', datetime.datetime(2014, 12, 3, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1043'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 12, 3, 0, 0)), ('cancel_date', datetime.datetime(2014, 12, 4, 0, 0)), ('days_to_cancel', 1), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1130'), ('status', 'canceled'), ('join_date', datetime.datetime(2014, 12, 3, 0, 0)), ('cancel_date', datetime.datetime(2015, 1, 25, 0, 0)), ('days_to_cancel', 53), ('is_udacity', False), ('is_canceled', True)])
# ...
# OrderedDict([('account_key', '1143'), ('status', 'current'), ('join_date', datetime.datetime(2015, 8, 11, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '931'), ('status', 'current'), ('join_date', datetime.datetime(2015, 8, 11, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1056'), ('status', 'current'), ('join_date', datetime.datetime(2015, 8, 12, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1235'), ('status', 'current'), ('join_date', datetime.datetime(2015, 8, 12, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '417'), ('status', 'current'), ('join_date', datetime.datetime(2015, 8, 12, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '794'), ('status', 'current'), ('join_date', datetime.datetime(2015, 8, 13, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '921'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 8, 17, 0, 0)), ('cancel_date', datetime.datetime(2015, 8, 21, 0, 0)), ('days_to_cancel', 4), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '816'), ('status', 'current'), ('join_date', datetime.datetime(2015, 8, 20, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1269'), ('status', 'current'), ('join_date', datetime.datetime(2015, 8, 21, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1067'), ('status', 'current'), ('join_date', datetime.datetime(2015, 8, 22, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1157'), ('status', 'current'), ('join_date', datetime.datetime(2015, 8, 22, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '980'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 4, 8, 0, 0)), ('cancel_date', datetime.datetime(2015, 4, 14, 0, 0)), ('days_to_cancel', 6), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '726'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 4, 8, 0, 0)), ('cancel_date', datetime.datetime(2015, 5, 15, 0, 0)), ('days_to_cancel', 37), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '177'), ('status', 'current'), ('join_date', datetime.datetime(2015, 4, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '797'), ('status', 'current'), ('join_date', datetime.datetime(2015, 4, 24, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '49'), ('status', 'current'), ('join_date', datetime.datetime(2015, 4, 24, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '376'), ('status', 'current'), ('join_date', datetime.datetime(2015, 5, 5, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1004'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 5, 6, 0, 0)), ('cancel_date', datetime.datetime(2015, 5, 8, 0, 0)), ('days_to_cancel', 2), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1024'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 5, 6, 0, 0)), ('cancel_date', datetime.datetime(2015, 5, 11, 0, 0)), ('days_to_cancel', 5), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '228'), ('status', 'current'), ('join_date', datetime.datetime(2015, 5, 7, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '173'), ('status', 'current'), ('join_date', datetime.datetime(2015, 5, 7, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '422'), ('status', 'current'), ('join_date', datetime.datetime(2015, 5, 8, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '236'), ('status', 'current'), ('join_date', datetime.datetime(2015, 5, 10, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '779'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 5, 10, 0, 0)), ('cancel_date', datetime.datetime(2015, 6, 18, 0, 0)), ('days_to_cancel', 39), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '881'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 5, 11, 0, 0)), ('cancel_date', datetime.datetime(2015, 5, 14, 0, 0)), ('days_to_cancel', 3), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1182'), ('status', 'current'), ('join_date', datetime.datetime(2015, 5, 11, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '287'), ('status', 'current'), ('join_date', datetime.datetime(2015, 5, 11, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '648'), ('status', 'current'), ('join_date', datetime.datetime(2015, 5, 11, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1249'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 5, 11, 0, 0)), ('cancel_date', datetime.datetime(2015, 7, 18, 0, 0)), ('days_to_cancel', 68), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '519'), ('status', 'current'), ('join_date', datetime.datetime(2015, 5, 11, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1099'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 5, 11, 0, 0)), ('cancel_date', datetime.datetime(2015, 7, 18, 0, 0)), ('days_to_cancel', 68), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '566'), ('status', 'current'), ('join_date', datetime.datetime(2015, 5, 12, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '846'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 5, 12, 0, 0)), ('cancel_date', datetime.datetime(2015, 6, 19, 0, 0)), ('days_to_cancel', 38), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1052'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 5, 12, 0, 0)), ('cancel_date', datetime.datetime(2015, 7, 19, 0, 0)), ('days_to_cancel', 68), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1059'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 5, 12, 0, 0)), ('cancel_date', datetime.datetime(2015, 5, 18, 0, 0)), ('days_to_cancel', 6), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '661'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 5, 12, 0, 0)), ('cancel_date', datetime.datetime(2015, 6, 19, 0, 0)), ('days_to_cancel', 38), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '852'), ('status', 'current'), ('join_date', datetime.datetime(2015, 5, 12, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '491'), ('status', 'current'), ('join_date', datetime.datetime(2015, 5, 12, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '445'), ('status', 'current'), ('join_date', datetime.datetime(2015, 5, 13, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '644'), ('status', 'current'), ('join_date', datetime.datetime(2015, 5, 13, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '68'), ('status', 'current'), ('join_date', datetime.datetime(2015, 5, 13, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '489'), ('status', 'current'), ('join_date', datetime.datetime(2015, 6, 1, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '911'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 6, 1, 0, 0)), ('cancel_date', datetime.datetime(2015, 6, 3, 0, 0)), ('days_to_cancel', 2), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1206'), ('status', 'current'), ('join_date', datetime.datetime(2015, 6, 3, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '414'), ('status', 'current'), ('join_date', datetime.datetime(2015, 6, 7, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '226'), ('status', 'current'), ('join_date', datetime.datetime(2015, 6, 8, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '2'), ('status', 'current'), ('join_date', datetime.datetime(2015, 6, 8, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1187'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 6, 9, 0, 0)), ('cancel_date', datetime.datetime(2015, 6, 15, 0, 0)), ('days_to_cancel', 6), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1274'), ('status', 'current'), ('join_date', datetime.datetime(2015, 7, 8, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '218'), ('status', 'current'), ('join_date', datetime.datetime(2015, 7, 8, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '324'), ('status', 'current'), ('join_date', datetime.datetime(2015, 7, 9, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '891'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 7, 9, 0, 0)), ('cancel_date', datetime.datetime(2015, 7, 15, 0, 0)), ('days_to_cancel', 6), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1000'), ('status', 'current'), ('join_date', datetime.datetime(2015, 7, 11, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '973'), ('status', 'current'), ('join_date', datetime.datetime(2015, 7, 13, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '806'), ('status', 'current'), ('join_date', datetime.datetime(2015, 7, 15, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1178'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 7, 16, 0, 0)), ('cancel_date', datetime.datetime(2015, 8, 7, 0, 0)), ('days_to_cancel', 22), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '832'), ('status', 'current'), ('join_date', datetime.datetime(2015, 7, 16, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1232'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 7, 16, 0, 0)), ('cancel_date', datetime.datetime(2015, 7, 17, 0, 0)), ('days_to_cancel', 1), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1057'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 7, 17, 0, 0)), ('cancel_date', datetime.datetime(2015, 7, 21, 0, 0)), ('days_to_cancel', 4), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '689'), ('status', 'current'), ('join_date', datetime.datetime(2015, 7, 17, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1278'), ('status', 'current'), ('join_date', datetime.datetime(2015, 7, 17, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1272'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 7, 17, 0, 0)), ('cancel_date', datetime.datetime(2015, 7, 23, 0, 0)), ('days_to_cancel', 6), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '438'), ('status', 'current'), ('join_date', datetime.datetime(2015, 7, 17, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '992'), ('status', 'current'), ('join_date', datetime.datetime(2015, 7, 17, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '575'), ('status', 'current'), ('join_date', datetime.datetime(2015, 7, 17, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '807'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 7, 20, 0, 0)), ('cancel_date', datetime.datetime(2015, 7, 22, 0, 0)), ('days_to_cancel', 2), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '1298'), ('status', 'current'), ('join_date', datetime.datetime(2015, 8, 11, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '751'), ('status', 'current'), ('join_date', datetime.datetime(2015, 8, 11, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1176'), ('status', 'current'), ('join_date', datetime.datetime(2015, 8, 12, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1110'), ('status', 'current'), ('join_date', datetime.datetime(2015, 8, 13, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '1116'), ('status', 'canceled'), ('join_date', datetime.datetime(2015, 8, 15, 0, 0)), ('cancel_date', datetime.datetime(2015, 8, 18, 0, 0)), ('days_to_cancel', 3), ('is_udacity', False), ('is_canceled', True)])
# OrderedDict([('account_key', '874'), ('status', 'current'), ('join_date', datetime.datetime(2015, 8, 22, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# OrderedDict([('account_key', '686'), ('status', 'current'), ('join_date', datetime.datetime(2015, 8, 23, 0, 0)), ('cancel_date', None), ('days_to_cancel', None), ('is_udacity', False), ('is_canceled', False)])
# 1548

# %% [markdown]
# ## Tracking Down the Remaining Problems

# %%
# Create a set of the account keys for all Udacity test accounts
udacity_test_accounts = set()
for enrollment in enrollments:
    if enrollment['is_udacity']:
        udacity_test_accounts.add(enrollment['account_key'])
len(udacity_test_accounts)
# Out:
# 6

# %%
# Given some data with an account_key field, removes any records corresponding to Udacity test accounts
def remove_udacity_accounts(data):
    non_udacity_data = []
    for data_point in data:
        if data_point['account_key'] not in udacity_test_accounts:
            non_udacity_data.append(data_point)
    return non_udacity_data

# %%
# Remove Udacity test accounts from all three tables
non_udacity_enrollments = remove_udacity_accounts(enrollments)
non_udacity_engagement = remove_udacity_accounts(daily_engagement)
non_udacity_submissions = remove_udacity_accounts(project_submissions)

print len(non_udacity_enrollments)
print len(non_udacity_engagement)
print len(non_udacity_submissions)
# Out:
#   File "<ipython-input-62-d66498c1a6ee>", line 6
#     print len(non_udacity_enrollments)
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Refining the Question

# %%
paid_students = {}
for enrollment in non_udacity_enrollments:
    if (not enrollment['is_canceled'] or
            enrollment['days_to_cancel'] > 7):
        account_key = enrollment['account_key']
        enrollment_date = enrollment['join_date']
        if (account_key not in paid_students or
                enrollment_date > paid_students[account_key]):
            paid_students[account_key] = enrollment_date
len(paid_students)

## Create a dictionary named paid_students containing all students who either
## haven't canceled yet or who remained enrolled for more than 7 days. The keys
## should be account keys, and the values should be the date the student enrolled.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-7cde51d2f3d4> in <module>()
#       1 paid_students = {}
# ----> 2 for enrollment in non_udacity_enrollments:
#       3     if (not enrollment['is_canceled'] or
#       4             enrollment['days_to_cancel'] > 7):
#       5         account_key = enrollment['account_key']
#
# NameError: name 'non_udacity_enrollments' is not defined

# %% [markdown]
# ## Getting Data from First Week

# %%
# Takes a student's join date and the date of a specific engagement record,
# and returns True if that engagement record happened within one week
# of the student joining.
def within_one_week(join_date, engagement_date):
    time_delta = engagement_date - join_date
    return time_delta.days < 7

# %%
def within_one_week(join_date, engagement_date):
    time_delta = engagement_date - join_date
    return time_delta.days < 7

def remove_free_trial_cancels(data):
    new_data = []
    for data_point in data:
        if data_point['account_key'] in paid_students:
            new_data.append(data_point)
    return new_data

paid_enrollments = remove_free_trial_cancels(non_udacity_enrollments)
paid_engagement = remove_free_trial_cancels(non_udacity_engagement)
paid_submissions = remove_free_trial_cancels(non_udacity_submissions)

print len(paid_enrollments)
print len(paid_engagement)
print len(paid_submissions)

paid_engagement_in_first_week = []
for engagement_record in paid_engagement:
    account_key = engagement_record['account_key']
    join_date = paid_students[account_key]
    engagement_record_date = engagement_record['utc_date']

    if within_one_week(join_date, engagement_record_date):
         paid_engagement_in_first_week.append(engagement_record)

len(paid_engagement_in_first_week)

## Create a list of rows from the engagement table including only rows where
## the student is one of the paid students you just found, and the date is within
## one week of the student's join date.

paid_engagement_in_first_week =

# %% [markdown]
# ## Exploring Student Engagement

# %%
from collections import defaultdict

# Create a dictionary of engagement grouped by student.
# The keys are account keys, and the values are lists of engagement records.
engagement_by_account = defaultdict(list)
for engagement_record in paid_engagement_in_first_week:
    account_key = engagement_record['account_key']
    engagement_by_account[account_key].append(engagement_record)

# %%
# Create a dictionary with the total minutes each student spent in the classroom during the first week.
# The keys are account keys, and the values are numbers (total minutes)
total_minutes_by_account = {}
for account_key, engagement_for_student in engagement_by_account.items():
    total_minutes = 0
    for engagement_record in engagement_for_student:
        total_minutes += engagement_record['total_minutes_visited']
    total_minutes_by_account[account_key] = total_minutes

# %%
import numpy as np

# Summarize the data about minutes spent in the classroom
total_minutes = total_minutes_by_account.values()
print 'Mean:', np.mean(total_minutes)
print 'Standard deviation:', np.std(total_minutes)
print 'Minimum:', np.min(total_minutes)
print 'Maximum:', np.max(total_minutes)

# %% [markdown]
# ## Debugging Data Analysis Code

# %%
student_with_max_minutes = None
max_minutes = 0

for student, total_minutes in total_minutes_by_account.items():
    if total_minutes > max_minutes:
        max_minutes = total_minutes
        student_with_max_minutes = student

max_minutes

for engagement_record in paid_engagement_in_first_week:
    if engagement_record['account_key'] == student_with_max_minutes:
        print engagement_record

## Go through a similar process as before to see if there is a problem.
## Locate at least one surprising piece of data, output it, and take a look at it.

# %% [markdown]
# ## Lessons Completed in First Week

# %%
#####################################
#                 9                 #
#####################################
from collections import defaultdict

def group_data(data, key_name):
    grouped_data = defaultdict(list)
    for data_point in data:
        key = data_point[key_name]
        grouped_data[key].append(data_point)
    return grouped_data

engagement_by_account = group_data(paid_engagement_in_first_week,
                                   'account_key')

def sum_grouped_items(grouped_data, field_name):
    summed_data = {}
    for key, data_points in grouped_data.items():
        total = 0
        for data_point in data_points:
            total += data_point[field_name]
        summed_data[key] = total
    return summed_data

total_minutes_by_account = sum_grouped_items(engagement_by_account,
                                             'total_minutes_visited')

import numpy as np

def describe_data(data):
    print 'Mean:', np.mean(data)
    print 'Standard deviation:', np.std(data)
    print 'Minimum:', np.min(data)
    print 'Maximum:', np.max(data)

describe_data(total_minutes_by_account.values())

## Adapt the code above to find the mean, standard deviation, minimum, and maximum for
## the number of lessons completed by each student during the first week. Try creating
## one or more functions to re-use the code above.
lessons_completed_by_account = sum_grouped_items(engagement_by_account,
                                                 'lessons_completed')
describe_data(lessons_completed_by_account.values())

# %% [markdown]
# ## Number of Visits in First Week

# %%
######################################
#                 10                 #

subway_project_lesson_keys = ['746169184', '3176718735']

pass_subway_project = set()

for submission in paid_submissions:
    project = submission['lesson_key']
    rating = submission['assigned_rating']    

    if ((project in subway_project_lesson_keys) and
            (rating == 'PASSED' or rating == 'DISTINCTION')):
        pass_subway_project.add(submission['account_key'])

len(pass_subway_project)

passing_engagement = []
non_passing_engagement = []

for engagement_record in paid_engagement_in_first_week:
    if engagement_record['account_key'] in pass_subway_project:
        passing_engagement.append(engagement_record)
    else:
        non_passing_engagement.append(engagement_record)

print len(passing_engagement)
print len(non_passing_engagement)

for engagement_record in paid_engagement:
    if engagement_record['num_courses_visited'] > 0:
        engagement_record['has_visited'] = 1
    else:
        engagement_record['has_visited'] = 0

days_visited_by_account = sum_grouped_items(engagement_by_account,
                                            'has_visited')
describe_data(days_visited_by_account.values())

## Find the mean, standard deviation, minimum, and maximum for the number of
## days each student visits the classroom during the first week.

# %% [markdown]
# ## Splitting out Passing Students

# %%
######################################
#                 11                 #
subway_project_lesson_keys = ['746169184', '3176718735']

pass_subway_project = set()

for submission in paid_submissions:
    project = submission['lesson_key']
    rating = submission['assigned_rating']    

    if ((project in subway_project_lesson_keys) and
            (rating == 'PASSED' or rating == 'DISTINCTION')):
        pass_subway_project.add(submission['account_key'])

len(pass_subway_project)

passing_engagement = []
non_passing_engagement = []

for engagement_record in paid_engagement_in_first_week:
    if engagement_record['account_key'] in pass_subway_project:
        passing_engagement.append(engagement_record)
    else:
        non_passing_engagement.append(engagement_record)

print len(passing_engagement)
print len(non_passing_engagement

## Create two lists of engagement data for paid students in the first week.
## The first list should contain data for students who eventually pass the
## subway project, and the second list should contain data for students
## who do not.

subway_project_lesson_keys = ['746169184', '3176718735']

passing_engagement =
non_passing_engagement =

# %% [markdown]
# ## Comparing the Two Student Groups

# %%
######################################
#                 12                 #
passing_engagement_by_account = group_data(passing_engagement,
                                           'account_key')
non_passing_engagement_by_account = group_data(non_passing_engagement,
                                               'account_key')

print 'non-passing students:'
non_passing_minutes = sum_grouped_items(
    non_passing_engagement_by_account,
    'total_minutes_visited'
)
describe_data(non_passing_minutes.values())
​
print 'passing students:'
passing_minutes = sum_grouped_items(
    passing_engagement_by_account,
    'total_minutes_visited'
)
describe_data(passing_minutes.values())

print 'non-passing students:'
non_passing_lessons = sum_grouped_items(
    non_passing_engagement_by_account,
    'lessons_completed'
)
describe_data(non_passing_lessons.values())

print 'passing students:'
passing_lessons = sum_grouped_items(
    passing_engagement_by_account,
    'lessons_completed'
)
describe_data(passing_lessons.values())

print 'non-passing students:'
non_passing_visits = sum_grouped_items(
    non_passing_engagement_by_account, 
    'has_visited'
)
describe_data(non_passing_visits.values())

print 'passing students:'
passing_visits = sum_grouped_items(
    passing_engagement_by_account,
    'has_visited'
)
describe_data(passing_visits.values())
## Compute some metrics you're interested in and see how they differ for
## students who pass the subway project vs. students who don't. A good
## starting point would be the metrics we looked at earlier (minutes spent
## in the classroom, lessons completed, and days visited).

# %% [markdown]
# ## Making Histograms

# %%
######################################
#                 13                 #
# %pylab inline

import matplotlib.pyplot as plt
import numpy as np

# Summarize the given data
def describe_data(data):
    print 'Mean:', np.mean(data)
    print 'Standard deviation:', np.std(data)
    print 'Minimum:', np.min(data)
    print 'Maximum:', np.max(data)
    plt.hist(data)
## Make histograms of the three metrics we looked at earlier for both
## students who passed the subway project and students who didn't. You
## might also want to make histograms of any other metrics you examined.

# %% [markdown]
# ## Improving Plots and Sharing Findings

# %%
######################################
#                 14                 #
import seaborn as sns

plt.hist(non_passing_visits.values(), bins=8)
plt.xlabel('Number of days')
plt.title('Distribution of classroom visits in the first week ' + 
          'for students who do not pass the subway project')

plt.hist(passing_visits.values(), bins=8)
plt.xlabel('Number of days')
plt.title('Distribution of classroom visits in the first week ' + 
          'for students who pass the subway project')
## Make a more polished version of at least one of your visualizations
## from earlier. Try importing the seaborn library to make the visualization
## look better, adding axis labels and a title, and changing one or more
## arguments to the hist() function.
